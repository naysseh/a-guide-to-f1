# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/results.csv', header=0)
# a= np.genfromtxt('data/results.csv', delimiter=',')

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
fastDict = []
uniqueRaces = df.raceId.unique()
# print(df.iloc[[11141]])
df_no_n = df[df.fastestLapTime.str.replace("\\","") != 'N']
for rID in uniqueRaces:
    rowsByRId = df_no_n[df_no_n.raceId == rID]
    fastestLap = rowsByRId[rowsByRId.fastestLapTime == rowsByRId.fastestLapTime.min()]
    fastDict.append(fastestLap)

result = pd.concat(fastDict)
print(result)
# Out:
# /var/folders/hh/q1jrmqbn74j2stf45vktvy4c0000gn/T/ipykernel_50141/3310438391.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_no_n = df[df.fastestLapTime.str.replace("\\","") != 'N']
#        resultId  raceId  driverId  constructorId number  grid position  \
# 4             5      18         5              1     23     3        5
# 27           28      19         2              2      3     5        6
# 48           49      20         5              1     23     5        5
# 66           67      21         8              6      1     1        1
# 90           91      22         8              6      1     4        3
# ...         ...     ...       ...            ...    ...   ...      ...
# 25755     25761    1092       855             51     24    14       16
# ...

# %%
result.to_csv('races_fastest_times.csv', index=False)
